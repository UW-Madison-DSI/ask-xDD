# %%
import requests

data = {
    "question": "What is the incubation period of COVID-19?",
    "top_k": 1,
    "doc_type": "paragraph",
}

response = requests.post(
    "http://localhost:4502/", headers={"Content-Type": "application/json"}, json=data
)

response.json()
