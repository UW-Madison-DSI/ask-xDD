# %% [markdown]
# # Show and tell: selected generator

# %%
# !pip install bert_score
# Out:
# Collecting bert_score
#   Using cached bert_score-0.3.13-py3-none-any.whl (61 kB)
# Requirement already satisfied: torch>=1.0.0 in c:\users\clo36\miniconda3\envs\askem\lib\site-packages (from bert_score) (2.0.1)
# Requirement already satisfied: pandas>=1.0.1 in c:\users\clo36\miniconda3\envs\askem\lib\site-packages (from bert_score) (2.0.2)
# Requirement already satisfied: transformers>=3.0.0 in c:\users\clo36\miniconda3\envs\askem\lib\site-packages (from bert_score) (4.25.1)
# Requirement already satisfied: numpy in c:\users\clo36\miniconda3\envs\askem\lib\site-packages (from bert_score) (1.24.3)
# Requirement already satisfied: requests in c:\users\clo36\miniconda3\envs\askem\lib\site-packages (from bert_score) (2.28.2)
# Requirement already satisfied: tqdm>=4.31.1 in c:\users\clo36\miniconda3\envs\askem\lib\site-packages (from bert_score) (4.65.0)
# Collecting matplotlib (from bert_score)
#   Using cached matplotlib-3.7.1-cp39-cp39-win_amd64.whl (7.6 MB)
# Requirement already satisfied: packaging>=20.9 in c:\users\clo36\miniconda3\envs\askem\lib\site-packages (from bert_score) (23.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\clo36\miniconda3\envs\askem\lib\site-packages (from pandas>=1.0.1->bert_score) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\clo36\miniconda3\envs\askem\lib\site-packages (from pandas>=1.0.1->bert_score) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\clo36\miniconda3\envs\askem\lib\site-packages (from pandas>=1.0.1->bert_score) (2023.3)
# Requirement already satisfied: filelock in c:\users\clo36\miniconda3\envs\askem\lib\site-packages (from torch>=1.0.0->bert_score) (3.12.0)
# Requirement already satisfied: typing-extensions in c:\users\clo36\miniconda3\envs\askem\lib\site-packages (from torch>=1.0.0->bert_score) (4.5.0)
# Requirement already satisfied: sympy in c:\users\clo36\miniconda3\envs\askem\lib\site-packages (from torch>=1.0.0->bert_score) (1.12)
# Requirement already satisfied: networkx in c:\users\clo36\miniconda3\envs\askem\lib\site-packages (from torch>=1.0.0->bert_score) (3.1)
# Requirement already satisfied: jinja2 in c:\users\clo36\miniconda3\envs\askem\lib\site-packages (from torch>=1.0.0->bert_score) (3.1.2)
# Requirement already satisfied: colorama in c:\users\clo36\miniconda3\envs\askem\lib\site-packages (from tqdm>=4.31.1->bert_score) (0.4.6)
# Requirement already satisfied: huggingface-hub<1.0,>=0.10.0 in c:\users\clo36\miniconda3\envs\askem\lib\site-packages (from transformers>=3.0.0->bert_score) (0.15.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\clo36\miniconda3\envs\askem\lib\site-packages (from transformers>=3.0.0->bert_score) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\clo36\miniconda3\envs\askem\lib\site-packages (from transformers>=3.0.0->bert_score) (2023.5.5)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in c:\users\clo36\miniconda3\envs\askem\lib\site-packages (from transformers>=3.0.0->bert_score) (0.13.3)
# Collecting contourpy>=1.0.1 (from matplotlib->bert_score)
#   Using cached contourpy-1.0.7-cp39-cp39-win_amd64.whl (160 kB)
# Collecting cycler>=0.10 (from matplotlib->bert_score)
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting fonttools>=4.22.0 (from matplotlib->bert_score)
#   Downloading fonttools-4.39.4-py3-none-any.whl (1.0 MB)
#                                               0.0/1.0 MB ? eta -:--:--
#      -                                        0.0/1.0 MB 640.0 kB/s eta 0:00:02
#      --                                       0.1/1.0 MB 975.2 kB/s eta 0:00:01
#      ----------                               0.3/1.0 MB 2.2 MB/s eta 0:00:01
#      ---------------------------------------  1.0/1.0 MB 5.8 MB/s eta 0:00:01
#      ---------------------------------------- 1.0/1.0 MB 5.8 MB/s eta 0:00:00
# Collecting kiwisolver>=1.0.1 (from matplotlib->bert_score)
#   Using cached kiwisolver-1.4.4-cp39-cp39-win_amd64.whl (55 kB)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\clo36\miniconda3\envs\askem\lib\site-packages (from matplotlib->bert_score) (9.5.0)
# Collecting pyparsing>=2.3.1 (from matplotlib->bert_score)
#   Using cached pyparsing-3.0.9-py3-none-any.whl (98 kB)
# Collecting importlib-resources>=3.2.0 (from matplotlib->bert_score)
#   Using cached importlib_resources-5.12.0-py3-none-any.whl (36 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\clo36\miniconda3\envs\askem\lib\site-packages (from requests->bert_score) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\clo36\miniconda3\envs\askem\lib\site-packages (from requests->bert_score) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\clo36\miniconda3\envs\askem\lib\site-packages (from requests->bert_score) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\clo36\miniconda3\envs\askem\lib\site-packages (from requests->bert_score) (2023.5.7)
# Requirement already satisfied: fsspec in c:\users\clo36\miniconda3\envs\askem\lib\site-packages (from huggingface-hub<1.0,>=0.10.0->transformers>=3.0.0->bert_score) (2023.5.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\clo36\miniconda3\envs\askem\lib\site-packages (from importlib-resources>=3.2.0->matplotlib->bert_score) (3.15.0)
# Requirement already satisfied: six>=1.5 in c:\users\clo36\miniconda3\envs\askem\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.0.1->bert_score) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\clo36\miniconda3\envs\askem\lib\site-packages (from jinja2->torch>=1.0.0->bert_score) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in c:\users\clo36\miniconda3\envs\askem\lib\site-packages (from sympy->torch>=1.0.0->bert_score) (1.3.0)
# Installing collected packages: pyparsing, kiwisolver, importlib-resources, fonttools, cycler, contourpy, matplotlib, bert_score
# Successfully installed bert_score-0.3.13 contourpy-1.0.7 cycler-0.11.0 fonttools-4.39.4 importlib-resources-5.12.0 kiwisolver-1.4.4 matplotlib-3.7.1 pyparsing-3.0.9

# %%
import torch
from askem._experimental.data import get_covid_qa
from askem.generator.app import get_generator
from askem._experimental.eval import showcase

# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

dataset = get_covid_qa(split="test")
generator = get_generator(device="cpu")
# Out:
# Downloading builder script: 100%|██████████| 4.80k/4.80k [00:00<?, ?B/s]
# Downloading metadata: 100%|██████████| 1.95k/1.95k [00:00<?, ?B/s]
# Downloading readme: 100%|██████████| 5.61k/5.61k [00:00<00:00, 5.73MB/s]
# Downloading and preparing dataset covid_qa_deepset/covid_qa_deepset to C:/Users/clo36/.cache/huggingface/datasets/covid_qa_deepset/covid_qa_deepset/1.0.0/fb886523842e312176f92ec8e01e77a08fa15a694f5741af6fc42796ee9c8c46...
# Downloading data: 4.42MB [00:00, 28.7MB/s]
# Dataset covid_qa_deepset downloaded and prepared to C:/Users/clo36/.cache/huggingface/datasets/covid_qa_deepset/covid_qa_deepset/1.0.0/fb886523842e312176f92ec8e01e77a08fa15a694f5741af6fc42796ee9c8c46. Subsequent calls will reuse this data.
# 100%|██████████| 1/1 [00:00<00:00, 137.65it/s]

# %%
showcase(dataset, generator)
# showcase(dataset, generator, idx=165) # worst?
# Out:
# Question 267: What is a drawback of Ad5 vector?
#
# Correct answer:
# preexisting immunity,
#
# Predicted answer:
